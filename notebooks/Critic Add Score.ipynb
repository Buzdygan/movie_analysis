# %%
import pandas as pd
import numpy as np
from storage import get_relevant_df
from termcolor import colored
from IPython.display import display, Markdown
from sklearn.metrics import classification_report, roc_auc_score

# %%
relevant_df = get_relevant_df()

# %%
def compute_add_score(rows):
    fresh_score, rotten_score = 1, 0
    scored = rows[rows.original_score.notnull()]
    if len(scored) > 0:
        fresh = scored[scored.fresh == True]
        if len(fresh) > 0:
            fresh_score = fresh['original_score'].mean()
        rotten = scored[scored.fresh == False]
        if len(rotten) > 0:
            rotten_score = rotten['original_score'].mean()
    return pd.Series([fresh_score, rotten_score])

# %%
critic_score_df = relevant_df.groupby('reviewer_url', as_index=True).apply(compute_add_score).reset_index()

# %%
critic_score_df.columns = ['reviewer_url', 'fresh_score', 'rotten_score']

# %%
joined_df = pd.merge(relevant_df, critic_score_df, on='reviewer_url')

# %%
def choose_score(x):
    if np.isnan(x['original_score']):
        if x['fresh']:
            return x['fresh_score']
        else:
            return x['rotten_score']
    return x['original_score']

# %%
joined_df['score'] = joined_df.apply(choose_score, axis=1)

# %%
joined_df.drop(['fresh_score', 'rotten_score'], axis=1)
# Out:
#        winner                                      title  \
# 0        True                         The Shape of Water
# 1       False                                   The Post
# 2       False                                  Lady Bird
# 3       False  Three Billboards Outside Ebbing, Missouri
# 4       False                                    Get Out
# 5        True                         The Shape of Water
# 6       False                               Darkest Hour
# 7       False                                   The Post
# 8       False                                    Dunkirk
# 9       False                                  Lady Bird
# 10      False                             Phantom Thread
# 11      False  Three Billboards Outside Ebbing, Missouri
# 12      False                            Bridge of Spies
# 13      False                                The Martian
# 14      False                               The Revenant
# 15       True                                  Spotlight
# 16      False                              The Big Short
# 17      False                                       Room
# 18      False                              Hacksaw Ridge
# 19      False                             Hidden Figures
# 20       True                                  Moonlight
# 21      False                                     Fences
# 22      False                                    Arrival
# 23      False                                 La La Land
# 24       True                         The Shape of Water
# 25      False                               Darkest Hour
# 26      False                                   The Post
# 27      False  Three Billboards Outside Ebbing, Missouri
# 28      False                                    Get Out
# 29      False                              Hacksaw Ridge
# ...       ...                                        ...
# 27370   False                                    Arrival
# 27371   False                                    Arrival
# 27372   False                                    Arrival
# 27373   False                                    Arrival
# 27374   False                                 La La Land
# 27375   False                                    Arrival
# 27376   False                                    Arrival
# 27377   False                                    Arrival
# 27378   False                                    Arrival
# 27379   False                                    Arrival
# 27380   False                                    Arrival
# 27381   False                                    Arrival
# 27382   False                                    Arrival
# 27383   False                                    Arrival
# 27384   False                                    Arrival
# 27385   False                                    Arrival
# 27386   False                                 La La Land
# 27387   False                                 La La Land
# 27388   False                                 La La Land
# 27389   False                                 La La Land
# 27390   False                                 La La Land
# 27391   False                                 La La Land
# 27392   False                                 La La Land
# 27393   False                                 La La Land
# 27394   False                                 La La Land
# 27395   False                                 La La Land
# 27396   False                                 La La Land
# 27397   False                                 La La Land
# 27398   False                                 La La Land
# 27399   False                                 La La Land
#
#                               reviewer_url  fresh  original_score  year  \
# 0            /critic/ruben-peralta-rigaud/   True             NaN  2018
# 1            /critic/ruben-peralta-rigaud/   True             NaN  2018
# 2            /critic/ruben-peralta-rigaud/   True             NaN  2018
# 3            /critic/ruben-peralta-rigaud/   True             NaN  2018
# 4            /critic/ruben-peralta-rigaud/   True             NaN  2018
# 5           /critic/sebastian-zavala-kahn/   True        1.000000  2018
# 6           /critic/sebastian-zavala-kahn/   True        0.750000  2018
# 7           /critic/sebastian-zavala-kahn/   True        0.875000  2018
# 8           /critic/sebastian-zavala-kahn/   True        1.000000  2018
# 9           /critic/sebastian-zavala-kahn/   True        0.875000  2018
# 10          /critic/sebastian-zavala-kahn/   True        0.875000  2018
# 11          /critic/sebastian-zavala-kahn/   True        0.875000  2018
# 12          /critic/sebastian-zavala-kahn/   True        0.750000  2016
# 13          /critic/sebastian-zavala-kahn/   True             NaN  2016
# 14          /critic/sebastian-zavala-kahn/   True        0.875000  2016
# 15          /critic/sebastian-zavala-kahn/   True        1.000000  2016
# 16          /critic/sebastian-zavala-kahn/   True        0.875000  2016
# 17          /critic/sebastian-zavala-kahn/   True        1.000000  2016
# 18          /critic/sebastian-zavala-kahn/   True        0.875000  2017
# 19          /critic/sebastian-zavala-kahn/   True        0.750000  2017
# 20          /critic/sebastian-zavala-kahn/   True        1.000000  2017
# 21          /critic/sebastian-zavala-kahn/   True        0.750000  2017
# 22          /critic/sebastian-zavala-kahn/   True        1.000000  2017
# 23          /critic/sebastian-zavala-kahn/   True        0.875000  2017
# 24             /critic/diego-batlle-18293/   True        0.800000  2018
# 25             /critic/diego-batlle-18293/  False        0.600000  2018
# 26             /critic/diego-batlle-18293/   True        0.900000  2018
# 27             /critic/diego-batlle-18293/   True        0.800000  2018
# 28             /critic/diego-batlle-18293/   True             NaN  2018
# 29             /critic/diego-batlle-18293/   True        0.800000  2017
# ...                                    ...    ...             ...   ...
# 27370                /critic/felipe-tapia/   True             NaN  2017
# 27371               /critic/mike-daringer/   True             NaN  2017
# 27372              /critic/jack-bottomley/   True        1.000000  2017
# 27373             /critic/fernando-moreno/   True             NaN  2017
# 27374             /critic/fernando-moreno/   True             NaN  2017
# 27375                 /critic/janet-smith/   True             NaN  2017
# 27376             /critic/deborah-krieger/   True             NaN  2017
# 27377                /critic/saskia-baron/   True        0.800000  2017
# 27378             /critic/valerie-kalfrin/   True        0.900000  2017
# 27379               /critic/britton-peele/   True        0.857143  2017
# 27380                /critic/allen-salkin/   True        0.700000  2017
# 27381                /critic/matthew-lowe/   True        0.850000  2017
# 27382               /critic/lauren-warren/   True        0.900000  2017
# 27383                /critic/bill-stamets/   True             NaN  2017
# 27384           /critic/sasha-james-18709/   True        0.900000  2017
# 27385             /critic/carlota-mosegui/   True        0.900000  2017
# 27386             /critic/carlota-mosegui/   True        0.600000  2017
# 27387        /critic/juan-carlos-ugarelli/   True             NaN  2017
# 27388           /critic/carlos-caramantin/   True             NaN  2017
# 27389                /critic/linda-holmes/   True             NaN  2017
# 27390                /critic/erika-balsom/   True             NaN  2017
# 27391                  /critic/quim-casas/   True        0.600000  2017
# 27392           /critic/christina-newland/   True        0.800000  2017
# 27393                /critic/ryan-pollard/   True        1.000000  2017
# 27394              /critic/ian-barr-14222/   True             NaN  2017
# 27395  /critic/gonzalo-hernandez-espinosa/   True             NaN  2017
# 27396                  /critic/meg-watson/   True             NaN  2017
# 27397                 /critic/alicia-cohn/   True             NaN  2017
# 27398                 /critic/tara-watson/   True             NaN  2017
# 27399              /critic/terri-schwartz/   True        0.950000  2017
#
#           score
# 0      1.000000
# 1      1.000000
# 2      1.000000
# 3      1.000000
# 4      1.000000
# 5      1.000000
# 6      0.750000
# 7      0.875000
# 8      1.000000
# 9      0.875000
# 10     0.875000
# 11     0.875000
# 12     0.750000
# 13     0.888889
# 14     0.875000
# 15     1.000000
# 16     0.875000
# 17     1.000000
# 18     0.875000
# 19     0.750000
# 20     1.000000
# 21     0.750000
# 22     1.000000
# 23     0.875000
# 24     0.800000
# 25     0.600000
# 26     0.900000
# 27     0.800000
# 28     0.775000
# 29     0.800000
# ...         ...
# 27370  1.000000
# 27371  1.000000
# 27372  1.000000
# 27373  1.000000
# 27374  1.000000
# 27375  1.000000
# 27376  1.000000
# 27377  0.800000
# 27378  0.900000
# 27379  0.857143
# 27380  0.700000
# 27381  0.850000
# 27382  0.900000
# 27383  1.000000
# 27384  0.900000
# 27385  0.900000
# 27386  0.600000
# 27387  1.000000
# 27388  1.000000
# 27389  1.000000
# 27390  1.000000
# 27391  0.600000
# 27392  0.800000
# 27393  1.000000
# 27394  1.000000
# 27395  1.000000
# 27396  1.000000
# 27397  1.000000
# 27398  1.000000
# 27399  0.950000
#
# [27400 rows x 7 columns]

# %% [markdown]
# # Examining how many reviews have no score

# %%
relevant_df[relevant_df.reviewer_url == '/critic/kenneth-turan/'][relevant_df.fresh == False][relevant_df.original_score.notnull()]['original_score'].mean()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 0.44000000000000006

# %%
def has_score(x):
    null = len(x[x.original_score.isnull()])
    return pd.Series([len(x) - null, null])

# %%
ddf = relevant_df.groupby('reviewer_url', as_index=True).apply(has_score).reset_index()

# %%
ddf.columns = ['critic', 'nonnull', 'null']

# %%
ddf[ddf.nonnull == 0]['null'].sum()
# Out:
# 3343

# %%
len(relevant_df[relevant_df.original_score.isnull()])
# Out:
# 7000

# %%
len(relevant_df)
# Out:
# 27400

# %%
ddf[ddf.nonnull == 0].sort_values(by='null', ascending=False)
# Out:
#                               critic  nonnull  null
# 526         /critic/david-edelstein/        0   107
# 2089          /critic/todd-mccarthy/        0    86
# 1030        /critic/joe-morgenstern/        0    86
# 1335          /critic/louise-keller/        0    83
# 485            /critic/dana-stevens/        0    76
# 125          /critic/andrew-l-urban/        0    67
# 952           /critic/jeanne-kaplan/        0    66
# 542            /critic/david-kaplan/        0    66
# 1198            /critic/kelly-vance/        0    60
# 2150     /critic/victoria-alexander/        0    59
# 132           /critic/andrew-ohehir/        0    58
# 168            /critic/anthony-lane/        0    48
# 183            /critic/armond-white/        0    47
# 1909             /critic/sean-burns/        0    47
# 525             /critic/david-denby/        0    45
# 419         /critic/christopher-orr/        0    42
# 1334          /critic/louis-proyect/        0    39
# 622            /critic/ed-whitfield/        0    38
# 1702          /critic/philip-french/        0    37
# 2088         /critic/todd-jorgenson/        0    37
# 142              /critic/andy-klein/        0    36
# 850              /critic/j-hoberman/        0    36
# 1220            /critic/kevin-lally/        0    33
# 1846            /critic/ryan-gilbey/        0    33
# 2028         /critic/stuart-klawans/        0    32
# 135           /critic/andrew-sarris/        0    30
# 1712         /critic/prairie-miller/        0    29
# 230         /critic/betty-jo-tucker/        0    28
# 1248         /critic/kristian-m-lin/        0    27
# 1896          /critic/scott-foundas/        0    26
# ...                              ...      ...   ...
# 1293           /critic/leonardo-goi/        0     1
# 681          /critic/erik-henriksen/        0     1
# 1287          /critic/leo-goldsmith/        0     1
# 1286            /critic/lenika-cruz/        0     1
# 682            /critic/erika-balsom/        0     1
# 1282             /critic/lee-jutton/        0     1
# 1272  /critic/lauren-carroll-harris/        0     1
# 685            /critic/ernest-hardy/        0     1
# 1269            /critic/laura-fries/        0     1
# 1260             /critic/lara-zarum/        0     1
# 1310           /critic/linda-holmes/        0     1
# 676             /critic/erick-ortiz/        0     1
# 1405        /critic/mark-rabinowitz/        0     1
# 1324             /critic/liz-graham/        0     1
# 614             /critic/duncan-gray/        0     1
# 636          /critic/elena-nicolaou/        0     1
# 639      /critic/elisabeth-donnelly/        0     1
# 645            /critic/ellen-murray/        0     1
# 1378           /critic/maria-garcia/        0     1
# 646             /critic/ellin-stein/        0     1
# 1346       /critic/luis-miguel-cruz/        0     1
# 648             /critic/eloise-ross/        0     1
# 655           /critic/emily-yoshida/        0     1
# 1338        /critic/lucero-calderon/        0     1
# 1337      /critic/lucas-hilderbrand/        0     1
# 1336           /critic/luanne-brown/        0     1
# 657              /critic/emma-jones/        0     1
# 659           /critic/emma-paterson/        0     1
# 675          /critic/erick-gallardo/        0     1
# 1049           /critic/john-hiscock/        0     1
#
# [588 rows x 3 columns]

# %%
cdf = relevant_df[relevant_df.reviewer_url == '/critic/david-edelstein/']

# %%
roc_auc_score(cdf['winner'], cdf['fresh'])
# Out:
# 0.5202898550724637
